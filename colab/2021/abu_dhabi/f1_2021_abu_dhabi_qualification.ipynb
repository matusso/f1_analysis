# %% [markdown]
# <a href="https://colab.research.google.com/github/matusso/f1_analysis/blob/main/colab/2021/abu_dhabi/f1_2021_abu_dhabi_qualification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # F1 2021 - Abu Dhabi

# %%
# !sudo apt update && sudo apt upgrade
# !sudo apt install python3.8-full
# !python3.8 -m ensurepip 
# !pip install ipykernel fastf1
# !mkdir -p f1cache

# %% [markdown]
# ### Qualification Times - TimeDelta graph

# %%
# !rm -f qualification_times.py
# !wget https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2021/AbuDhabi/qualification_times.py
# !python3.8 ./qualification_times.py
# %matplotlib
from IPython.display import Image
Image('qualification_times.png')
# Out:
# --2022-01-21 19:37:31--  https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2021/AbuDhabi/qualification_times.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1796 (1.8K) [text/plain]
# Saving to: ‘qualification_times.py’
#
# qualification_times 100%[===================>]   1.75K  --.-KB/s    in 0s
#
# 2022-01-21 19:37:31 (20.5 MB/s) - ‘qualification_times.py’ saved [1796/1796]
#
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Qualifying [v2.1.13]
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# ...

# %% [markdown]
# ### Qualification Fastest Time - Telemetry Comparision [Hamilton vs. Verstapen]

# %%
# !rm -f qualification_speed_ham_ver.py
# !wget https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2021/AbuDhabi/qualification_speed_ham_ver.py
# !python3.8 ./qualification_speed_ham_ver.py
from IPython.display import Image
Image('fastest_lap_tel.png')
# Out:
# --2022-01-22 11:14:27--  https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2021/AbuDhabi/qualification_speed_ham_ver.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2395 (2.3K) [text/plain]
# Saving to: ‘qualification_speed_ham_ver.py’
#
# qualification_speed 100%[===================>]   2.34K  --.-KB/s    in 0s
#
# 2022-01-22 11:14:27 (16.4 MB/s) - ‘qualification_speed_ham_ver.py’ saved [2395/2395]
#
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# ...
