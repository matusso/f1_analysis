# %% [markdown]
# <a href="https://colab.research.google.com/github/matusso/f1_analysis/blob/main/colab/2019/monza/qualification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # F1 2019 - Monza

# %%
# !sudo apt update && sudo apt upgrade
# !sudo apt install python3.8-full
# !python3.8 -m ensurepip 
# !pip install ipykernel fastf1
# !mkdir -p f1cache
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [872 kB]
# ...

# %% [markdown]
# ### Qualification Times - TimeDelta graph

# %%
# !rm -f qualification_times.py
# !wget https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2019/Monza/qualification_times.py
# !python3.8 ./qualification_times.py
# %matplotlib
from IPython.display import Image
Image('qualification_times.png')
# Out:
# --2022-01-21 16:48:49--  https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2019/Monza/qualification_times.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1748 (1.7K) [text/plain]
# Saving to: ‘qualification_times.py’
#
# qualification_times 100%[===================>]   1.71K  --.-KB/s    in 0s
#
# 2022-01-21 16:48:49 (27.1 MB/s) - ‘qualification_times.py’ saved [1748/1748]
#
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# ...

# %% [markdown]
# ### Qualification Fastest Time - Telemetry Comparision [Hamilton vs. Leclerc]

# %%
# !rm -f qualification_speed_ham_lec.py speed.png throttle.png brake.png
# !wget https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2019/Monza/qualification_speed_ham_lec.py
# !python3.8 ./qualification_speed_ham_lec.py


import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# %matplotlib inline

# figure size in inches optional
rcParams['figure.figsize'] = 40 ,20

# read images
img_A = mpimg.imread('speed.png')
img_B = mpimg.imread('brake.png')
img_C = mpimg.imread('throttle.png')

# display images
fig, ax = plt.subplots(1,3)
ax[0].imshow(img_A);
ax[1].imshow(img_B);
ax[2].imshow(img_C);
# Out:
# --2022-01-21 17:06:02--  https://raw.githubusercontent.com/matusso/f1_analysis/main/analysis/2019/Monza/qualification_speed_ham_lec.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1470 (1.4K) [text/plain]
# Saving to: ‘qualification_speed_ham_lec.py’
#
# qualification_speed 100%[===================>]   1.44K  --.-KB/s    in 0s
#
# 2022-01-21 17:06:02 (29.2 MB/s) - ‘qualification_speed_ham_lec.py’ saved [1470/1470]
#
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# ...
