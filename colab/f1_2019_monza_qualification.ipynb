# %% [markdown]
# <a href="https://colab.research.google.com/github/matusso/f1_analysis/blob/main/colab/f1_2019_monza_qualification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update && sudo apt-get upgrade
# !sudo apt-get install python3.8-full
# !python3.8 -m ensurepip 
# !pip install ipykernel fastf1

# %%
# !rm -f qual_times.py
# !mkdir -p f1cache
# !wget https://gist.githubusercontent.com/matusso/968d7f62bb25f8c267f2dd469bd60113/raw/a55eadcce4991dbf71d0e5cead5ffd8e4e9a8a0d/qual_times.py
# !python3.8 ./qual_times.py
# %matplotlib
from IPython.display import Image
Image('my_figure.png')
# Out:
# --2022-01-21 14:00:01--  https://gist.githubusercontent.com/matusso/968d7f62bb25f8c267f2dd469bd60113/raw/a55eadcce4991dbf71d0e5cead5ffd8e4e9a8a0d/qual_times.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1848 (1.8K) [text/plain]
# Saving to: ‘qual_times.py’
#
# qual_times.py       100%[===================>]   1.80K  --.-KB/s    in 0s
#
# 2022-01-21 14:00:01 (21.6 MB/s) - ‘qual_times.py’ saved [1848/1848]
#
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# ...

# %% [markdown]
# # New Section
